# %%
import csv
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
df = pd.read_csv('../Resources/data_frame_export.csv')
df
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0       Stokmarknes          75      NO  1584471102        93  68.56   14.91
# 1            Bethel          90      US  1584471103        81  41.37  -73.41
# 2              Bāfq          65      IR  1584471103        28  31.61   55.41
# 3         Bathsheba          40      BB  1584471103        58  13.22  -59.52
# 4            Atuona          20      PF  1584471103        76  -9.80 -139.03
# ..              ...         ...     ...         ...       ...    ...     ...
# 588          Cairns          40      AU  1584471240        78 -16.92  145.77
# 589       Neyshabur          78      IR  1584471240        59  36.21   58.80
# 590         Arkhara          99      RU  1584471241        96  49.42  130.08
# 591  Barkhera Kalān           0      IN  1584471241        53  28.45   79.80
# 592       San Roque          75      ES  1584471241        77  36.21   -5.38
#
#      Max Temp  Wind Speed
# ...

# %%
html_output = df.to_html()

# %%
soup = bs(html_output, 'html.parser')
print(soup.prettify())
# Out:
# <table border="1" class="dataframe">
#  <thead>
#   <tr style="text-align: right;">
#    <th>
#    </th>
#    <th>
#     City
#    </th>
#    <th>
#     Cloudiness
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Date
#    </th>
#    <th>
#     Humidity
#    </th>
#    <th>
#     Lat
#    </th>
#    <th>
#     Lon
#    </th>
#    <th>
#     Max Temp
#    </th>
#    <th>
#     Wind Speed
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <th>
#     0
#    </th>
#    <td>
#     Stokmarknes
#    </td>
#    <td>
#     75
#    </td>
#    <td>
#     NO
#    </td>
#    <td>
#     1584471102
#    </td>
#    <td>
#     93
#    </td>
#    <td>
#     68.56
#    </td>
#    <td>
#     14.91
#    </td>
#    <td>
#     37.99
#    </td>
#    <td>
#     6.93
#    </td>
#   </tr>
#   <tr>
#    <th>
#     1
#    </th>
#    <td>
#     Bethel
#    </td>
#    <td>
#     90
#    </td>
#    <td>
#     US
#    </td>
#    <td>
#     1584471103
#    </td>
#    <td>
#     81
#    </td>
# ...
